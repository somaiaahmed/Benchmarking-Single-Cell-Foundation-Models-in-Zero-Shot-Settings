# %%
# !pip install scanpy anndata
# Out:
# Collecting scanpy
#   Downloading scanpy-1.12.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting anndata
#   Downloading anndata-0.12.13-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from scanpy) (2026.4.22)
# Collecting fast-array-utils>=1.4 (from fast-array-utils[accel,sparse]>=1.4->scanpy)
#   Downloading fast_array_utils-1.4.1-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: h5py>=3.11 in /usr/local/lib/python3.12/dist-packages (from scanpy) (3.16.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.5.3)
# Collecting legacy-api-wrap>=1.5 (from scanpy)
#   Downloading legacy_api_wrap-1.5-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: matplotlib>=3.9 in /usr/local/lib/python3.12/dist-packages (from scanpy) (3.10.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from scanpy) (8.4.0)
# Requirement already satisfied: networkx>=2.8.8 in /usr/local/lib/python3.12/dist-packages (from scanpy) (3.6.1)
# Requirement already satisfied: numba>=0.60 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.60.0)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from scanpy) (2.0.2)
# Requirement already satisfied: packaging>=25 in /usr/local/lib/python3.12/dist-packages (from scanpy) (26.1)
# Collecting pandas>=2.3 (from scanpy)
#   Downloading pandas-3.0.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: patsy in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5.13 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.6.0)
# Requirement already satisfied: scikit-learn>=1.6 in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.6.1)
# Requirement already satisfied: scipy>=1.13 in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.16.3)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.13.2)
# Collecting session-info2 (from scanpy)
#   Downloading session_info2-0.4.1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.14.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from scanpy) (4.67.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from scanpy) (4.15.0)
# Requirement already satisfied: umap-learn>=0.5.12 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.5.12)
# Collecting array-api-compat>=1.7.1 (from anndata)
#   Downloading array_api_compat-1.14.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pandas>=2.3 (from scanpy)
#   Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 4.1 MB/s eta 0:00:00
# Collecting scverse-misc>=0.0.3 (from anndata)
#   Downloading scverse_misc-0.0.5-py3-none-any.whl.metadata (4.4 kB)
# Collecting zarr!=3.0.*,>=2.18.7 (from anndata)
#   Downloading zarr-3.2.1-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.60->scanpy) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.3->scanpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.3->scanpy) (2026.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6->scanpy) (3.6.0)
# Collecting donfig>=0.8 (from zarr!=3.0.*,>=2.18.7->anndata)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata) (1.8.0)
# Collecting numcodecs>=0.14 (from zarr!=3.0.*,>=2.18.7->anndata)
#   Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata) (6.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.9->scanpy) (1.17.0)
# Downloading scanpy-1.12.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 17.2 MB/s eta 0:00:00
# Downloading anndata-0.12.13-py3-none-any.whl (174 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.4/174.4 kB 5.2 MB/s eta 0:00:00
# Downloading array_api_compat-1.14.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 2.7 MB/s eta 0:00:00
# Downloading fast_array_utils-1.4.1-py3-none-any.whl (39 kB)
# Downloading legacy_api_wrap-1.5-py3-none-any.whl (10 kB)
# Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 29.8 MB/s eta 0:00:00
# Downloading scverse_misc-0.0.5-py3-none-any.whl (12 kB)
# Downloading zarr-3.2.1-py3-none-any.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.6/319.6 kB 13.5 MB/s eta 0:00:00
# Downloading session_info2-0.4.1-py3-none-any.whl (17 kB)
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 33.3 MB/s eta 0:00:00
# Installing collected packages: session-info2, numcodecs, legacy-api-wrap, fast-array-utils, donfig, array-api-compat, zarr, scverse-misc, pandas, anndata, scanpy
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# Successfully installed anndata-0.12.13 array-api-compat-1.14.0 donfig-0.8.1.post1 fast-array-utils-1.4.1 legacy-api-wrap-1.5 numcodecs-0.16.5 pandas-2.3.3 scanpy-1.12.1 scverse-misc-0.0.5 session-info2-0.4.1 zarr-3.2.1

# %%
# !pip install muon
# Out:
# Collecting muon
#   Downloading muon-0.1.7-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from muon) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from muon) (2.3.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from muon) (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from muon) (0.13.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from muon) (3.16.0)
# Requirement already satisfied: anndata in /usr/local/lib/python3.12/dist-packages (from muon) (0.12.13)
# Requirement already satisfied: scanpy in /usr/local/lib/python3.12/dist-packages (from muon) (1.12.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from muon) (1.6.1)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.12/dist-packages (from muon) (0.5.12)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from muon) (0.60.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from muon) (5.29.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from muon) (4.67.3)
# Collecting mudata (from muon)
#   Downloading mudata-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: array-api-compat>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from anndata->muon) (1.14.0)
# Requirement already satisfied: legacy-api-wrap in /usr/local/lib/python3.12/dist-packages (from anndata->muon) (1.5)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from anndata->muon) (8.4.0)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.12/dist-packages (from anndata->muon) (26.1)
# Requirement already satisfied: scipy!=1.17.0,>=1.12 in /usr/local/lib/python3.12/dist-packages (from anndata->muon) (1.16.3)
# Requirement already satisfied: scverse-misc>=0.0.3 in /usr/local/lib/python3.12/dist-packages (from anndata->muon) (0.0.5)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in /usr/local/lib/python3.12/dist-packages (from anndata->muon) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->muon) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->muon) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->muon) (2026.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->muon) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->muon) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->muon) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->muon) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->muon) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->muon) (3.3.2)
# Requirement already satisfied: session-info2 in /usr/local/lib/python3.12/dist-packages (from mudata->muon) (0.4.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->muon) (0.43.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from scanpy->muon) (2026.4.22)
# Requirement already satisfied: fast-array-utils>=1.4 in /usr/local/lib/python3.12/dist-packages (from fast-array-utils[accel,sparse]>=1.4->scanpy->muon) (1.4.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from scanpy->muon) (1.5.3)
# Requirement already satisfied: networkx>=2.8.8 in /usr/local/lib/python3.12/dist-packages (from scanpy->muon) (3.6.1)
# Requirement already satisfied: patsy in /usr/local/lib/python3.12/dist-packages (from scanpy->muon) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5.13 in /usr/local/lib/python3.12/dist-packages (from scanpy->muon) (0.6.0)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from scanpy->muon) (0.14.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from scanpy->muon) (4.15.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->muon) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->muon) (1.17.0)
# Requirement already satisfied: donfig>=0.8 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata->muon) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata->muon) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata->muon) (0.16.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata->muon) (6.0.3)
# Downloading muon-0.1.7-py3-none-any.whl (293 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.7/293.7 kB 3.4 MB/s eta 0:00:00
# Downloading mudata-0.3.8-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: mudata, muon
# Successfully installed mudata-0.3.8 muon-0.1.7

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !git clone https://github.com/minwoosun/UCE.git
# Out:
# Cloning into 'UCE'...
# remote: Enumerating objects: 151, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 151 (delta 66), reused 47 (delta 47), pack-reused 71 (from 1)
# Receiving objects: 100% (151/151), 67.75 KiB | 2.42 MiB/s, done.
# Resolving deltas: 100% (80/80), done.

# %%
# %cd UCE
# Out:
# /content/UCE

# %%
! pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (1.16.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.3.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (4.67.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (2.9.0+cpu)
# Requirement already satisfied: scanpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (1.12.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (1.13.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (2.32.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 3)) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 3)) (2026.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 5)) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 5)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 5)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 5)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 5)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 5)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 5)) (2026.2.0)
# Requirement already satisfied: anndata>=0.10.8 in /usr/local/lib/python3.12/dist-packages (from scanpy->-r requirements.txt (line 6)) (0.12.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from scanpy->-r requirements.txt (line 6)) (2026.4.22)
# Requirement already satisfied: fast-array-utils>=1.4 in /usr/local/lib/python3.12/dist-packages (from fast-array-utils[accel,sparse]>=1.4->scanpy->-r requirements.txt (line 6)) (1.4.1)
# Requirement already satisfied: h5py>=3.11 in /usr/local/lib/python3.12/dist-packages (from scanpy->-r requirements.txt (line 6)) (3.16.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from scanpy->-r requirements.txt (line 6)) (1.5.3)
# Requirement already satisfied: legacy-api-wrap>=1.5 in /usr/local/lib/python3.12/dist-packages (from scanpy->-r requirements.txt (line 6)) (1.5)
# Requirement already satisfied: matplotlib>=3.9 in /usr/local/lib/python3.12/dist-packages (from scanpy->-r requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from scanpy->-r requirements.txt (line 6)) (8.4.0)
# Requirement already satisfied: numba>=0.60 in /usr/local/lib/python3.12/dist-packages (from scanpy->-r requirements.txt (line 6)) (0.65.0)
# Requirement already satisfied: packaging>=25 in /usr/local/lib/python3.12/dist-packages (from scanpy->-r requirements.txt (line 6)) (26.1)
# Requirement already satisfied: patsy in /usr/local/lib/python3.12/dist-packages (from scanpy->-r requirements.txt (line 6)) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5.13 in /usr/local/lib/python3.12/dist-packages (from scanpy->-r requirements.txt (line 6)) (0.6.0)
# Requirement already satisfied: scikit-learn>=1.6 in /usr/local/lib/python3.12/dist-packages (from scanpy->-r requirements.txt (line 6)) (1.6.1)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from scanpy->-r requirements.txt (line 6)) (0.13.2)
# Requirement already satisfied: session-info2 in /usr/local/lib/python3.12/dist-packages (from scanpy->-r requirements.txt (line 6)) (0.4.1)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from scanpy->-r requirements.txt (line 6)) (0.14.6)
# Requirement already satisfied: umap-learn>=0.5.12 in /usr/local/lib/python3.12/dist-packages (from scanpy->-r requirements.txt (line 6)) (0.5.12)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate->-r requirements.txt (line 7)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate->-r requirements.txt (line 7)) (6.0.3)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate->-r requirements.txt (line 7)) (1.11.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate->-r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 8)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 8)) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 8)) (2.5.0)
# Requirement already satisfied: array-api-compat>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.10.8->scanpy->-r requirements.txt (line 6)) (1.14.0)
# Requirement already satisfied: scverse-misc>=0.0.3 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.10.8->scanpy->-r requirements.txt (line 6)) (0.0.5)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.10.8->scanpy->-r requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate->-r requirements.txt (line 7)) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate->-r requirements.txt (line 7)) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate->-r requirements.txt (line 7)) (0.24.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy->-r requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy->-r requirements.txt (line 6)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy->-r requirements.txt (line 6)) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy->-r requirements.txt (line 6)) (12.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.60->scanpy->-r requirements.txt (line 6)) (0.47.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6->scanpy->-r requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r requirements.txt (line 5)) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate->-r requirements.txt (line 7)) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate->-r requirements.txt (line 7)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate->-r requirements.txt (line 7)) (0.16.0)
# Requirement already satisfied: donfig>=0.8 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy->-r requirements.txt (line 6)) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy->-r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy->-r requirements.txt (line 6)) (0.16.5)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate->-r requirements.txt (line 7)) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate->-r requirements.txt (line 7)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate->-r requirements.txt (line 7)) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.21.0->accelerate->-r requirements.txt (line 7)) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate->-r requirements.txt (line 7)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate->-r requirements.txt (line 7)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub>=0.21.0->accelerate->-r requirements.txt (line 7)) (0.1.2)

# %% [markdown]
# ### run model on loaded data

# %%
! python eval_single_anndata.py --adata_path "/content/drive/MyDrive/GP_datasets/BoneMarrow/Bonemarrow_rna.h5ad" --dir "./"  --model_loc "minwoosun/uce-100m"
# Out:
# species_chrom.csv: 4.10MB [00:00, 29.6MB/s]
# all_tokens.torch: 100% 2.98G/2.98G [00:28<00:00, 106MB/s]
# species_offsets.pkl: 100% 139/139 [00:00<00:00, 172B/s]
# protein_embeddings/Danio_rerio.GRCz11.ge(…): 100% 537M/537M [00:08<00:00, 67.1MB/s]
# protein_embeddings/Homo_sapiens.GRCh38.g(…): 100% 411M/411M [00:07<00:00, 55.5MB/s]
# protein_embeddings/Macaca_fascicularis.M(…): 100% 315M/315M [00:02<00:00, 131MB/s]
# protein_embeddings/Macaca_mulatta.Mmul_1(…): 100% 348M/348M [00:06<00:00, 54.3MB/s]
# protein_embeddings/Microcebus_murinus.Mm(…): 100% 302M/302M [00:07<00:00, 43.1MB/s]
# protein_embeddings/Mus_musculus.GRCm39.g(…): 100% 464M/464M [00:03<00:00, 145MB/s]
# protein_embeddings/Sus_scrofa.Sscrofa11.(…): 100% 327M/327M [00:06<00:00, 52.8MB/s]
# protein_embeddings/Xenopus_tropicalis.Xe(…): 100% 281M/281M [00:05<00:00, 51.9MB/s]
# Download Complete!
# Proccessing Bonemarrow_rna
# 1083657.9
# Bonemarrow_rna (20000, 11798)
# Wrote Shapes Dict
# 11798
# Max Code: 612
# config.json: 100% 115/115 [00:00<00:00, 778kB/s]
# pytorch_model.bin: 100% 3.40G/3.40G [00:32<00:00, 106MB/s]
# Loaded model:
# minwoosun/uce-100m
# 100% 800/800 [02:40<00:00,  4.98it/s]
# *****Wrote Anndata to:*****
# ./Bonemarrow_rna_uce_adata.h5ad

# %%
import scanpy as sc
import anndata
emb_path = "/content/UCE/Bonemarrow_rna_uce_adata.h5ad"
adata_rna = sc.read_h5ad(emb_path)
adata_rna
# Out:
# AnnData object with n_obs × n_vars = 20000 × 11798
#     obs: 'GEX_n_genes_by_counts', 'GEX_pct_counts_mt', 'GEX_size_factors', 'GEX_phase', 'ADT_n_antibodies_by_counts', 'ADT_total_counts', 'ADT_iso_count', 'cell_type', 'batch', 'ADT_pseudotime_order', 'GEX_pseudotime_order', 'Samplename', 'Site', 'DonorNumber', 'Modality', 'VendorLot', 'DonorID', 'DonorAge', 'DonorBMI', 'DonorBloodType', 'DonorRace', 'Ethnicity', 'DonorGender', 'QCMeds', 'DonorSmoker', 'is_train', 'n_genes'
#     var: 'feature_types', 'gene_id', 'n_cells'
#     uns: 'dataset_id', 'genome', 'organism'
#     obsm: 'ADT_X_pca', 'ADT_X_umap', 'ADT_isotype_controls', 'GEX_X_pca', 'GEX_X_umap', 'X_uce'
#     layers: 'counts'

# %%
adata_rna.write_h5ad("/content/drive/MyDrive/GP_datasets/BoneMarrow/Bonemarrow_rna_embeddings_uce.h5ad")

# %%
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
import os
import subprocess
import pandas as pd
import numpy as np
import logging
import torch
import scanpy as sc
import anndata
logging.getLogger().setLevel(logging.ERROR)

warnings.filterwarnings("ignore")

# %%
adata_rna = sc.read_h5ad("/content/drive/MyDrive/GP_datasets/BoneMarrow/Bonemarrow_rna_embeddings_uce.h5ad")
adata_rna
# Out:
# AnnData object with n_obs × n_vars = 20000 × 11798
#     obs: 'GEX_n_genes_by_counts', 'GEX_pct_counts_mt', 'GEX_size_factors', 'GEX_phase', 'ADT_n_antibodies_by_counts', 'ADT_total_counts', 'ADT_iso_count', 'cell_type', 'batch', 'ADT_pseudotime_order', 'GEX_pseudotime_order', 'Samplename', 'Site', 'DonorNumber', 'Modality', 'VendorLot', 'DonorID', 'DonorAge', 'DonorBMI', 'DonorBloodType', 'DonorRace', 'Ethnicity', 'DonorGender', 'QCMeds', 'DonorSmoker', 'is_train', 'n_genes'
#     var: 'feature_types', 'gene_id', 'n_cells'
#     uns: 'dataset_id', 'genome', 'organism'
#     obsm: 'ADT_X_pca', 'ADT_X_umap', 'ADT_isotype_controls', 'GEX_X_pca', 'GEX_X_umap', 'X_uce'
#     layers: 'counts'

# %% [markdown]
# # Data exploring

# %%
adata_rna.obs.head()
# Out:
#                          GEX_n_genes_by_counts  GEX_pct_counts_mt  \
# TCATATCTCGAGAGCA-1-s3d7                   1477           5.861183
# TGCTTGCCAGTGACCC-1-s3d7                   1817           5.269367
# ACTACGAAGCTGGTGA-1-s3d7                   1353          11.183650
# TGTTGGACACTGTGAT-1-s2d1                   1281           9.208211
# ATGAGTCCATGGCGCT-1-s3d1                    557           8.790171
#
#                          GEX_size_factors GEX_phase  \
# TCATATCTCGAGAGCA-1-s3d7          0.923154       G2M
# TGCTTGCCAGTGACCC-1-s3d7          1.210090       G2M
# ACTACGAAGCTGGTGA-1-s3d7          0.832615       G2M
# TGTTGGACACTGTGAT-1-s2d1          1.036986        G1
# ATGAGTCCATGGCGCT-1-s3d1          0.740206       G2M
#
#                          ADT_n_antibodies_by_counts  ADT_total_counts  \
# TCATATCTCGAGAGCA-1-s3d7                         113             573.0
# TGCTTGCCAGTGACCC-1-s3d7                         109             617.0
# ACTACGAAGCTGGTGA-1-s3d7                         124             790.0
# TGTTGGACACTGTGAT-1-s2d1                          95             412.0
# ATGAGTCCATGGCGCT-1-s3d1                         133            1562.0
#
#                          ADT_iso_count   cell_type batch  \
# TCATATCTCGAGAGCA-1-s3d7            4.0  CD14+ Mono  s3d7
# TGCTTGCCAGTGACCC-1-s3d7            5.0  CD14+ Mono  s3d7
# ACTACGAAGCTGGTGA-1-s3d7            6.0  CD14+ Mono  s3d7
# TGTTGGACACTGTGAT-1-s2d1            3.0  CD14+ Mono  s2d1
# ATGAGTCCATGGCGCT-1-s3d1           21.0  CD14+ Mono  s3d1
#
#                          ADT_pseudotime_order  ...  DonorAge DonorBMI  \
# TCATATCTCGAGAGCA-1-s3d7                   NaN  ...        22     31.5
# TGCTTGCCAGTGACCC-1-s3d7                   NaN  ...        22     31.5
# ACTACGAAGCTGGTGA-1-s3d7                   NaN  ...        22     31.5
# TGTTGGACACTGTGAT-1-s2d1                   NaN  ...        34     24.8
# ATGAGTCCATGGCGCT-1-s3d1                   NaN  ...        34     24.8
#
#                         DonorBloodType DonorRace               Ethnicity  \
# TCATATCTCGAGAGCA-1-s3d7             A+     Asian  NOT HISPANIC OR LATINO
# TGCTTGCCAGTGACCC-1-s3d7             A+     Asian  NOT HISPANIC OR LATINO
# ACTACGAAGCTGGTGA-1-s3d7             A+     Asian  NOT HISPANIC OR LATINO
# TGTTGGACACTGTGAT-1-s2d1             B-     White      HISPANIC OR LATINO
# ATGAGTCCATGGCGCT-1-s3d1             B-     White      HISPANIC OR LATINO
#
#                          DonorGender  QCMeds  DonorSmoker     is_train n_genes
# TCATATCTCGAGAGCA-1-s3d7       Female    True    Nonsmoker        train    1468
# TGCTTGCCAGTGACCC-1-s3d7       Female    True    Nonsmoker        train    1803
# ACTACGAAGCTGGTGA-1-s3d7       Female    True    Nonsmoker        train    1343
# TGTTGGACACTGTGAT-1-s2d1         Male   False    Nonsmoker  iid_holdout    1274
# ATGAGTCCATGGCGCT-1-s3d1         Male   False    Nonsmoker        train     556
#
# [5 rows x 27 columns]

# %%
adata_rna.X
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float32'
# 	with 27685431 stored elements and shape (20000, 11798)>

# %%
adata_rna.obsm["X_uce"]
# Out:
# array([[ 0.02594296,  0.00394318, -0.01378957, ...,  0.0277936 ,
#          0.0482855 ,  0.02450585],
#        [ 0.02152645, -0.00779984,  0.00638758, ...,  0.04270147,
#          0.03814167,  0.03685741],
#        [ 0.01121855, -0.00424016, -0.01063906, ...,  0.01358634,
#          0.03459702,  0.01265327],
#        ...,
#        [ 0.05109596,  0.04451511, -0.04063061, ...,  0.00945928,
#          0.02614284, -0.04173455],
#        [ 0.04961716,  0.03943391, -0.0232768 , ...,  0.01228584,
#          0.0058342 , -0.03169142],
#        [ 0.03094897,  0.01389862, -0.04602706, ..., -0.02387662,
#          0.01799006, -0.01231632]], dtype=float32)

# %%
adata_adt=sc.read_h5ad("/content/drive/MyDrive/GP_datasets/BoneMarrow/Bonemarrow_adt.h5ad")
adata_adt
# Out:
# AnnData object with n_obs × n_vars = 20000 × 134
#     obs: 'GEX_n_genes_by_counts', 'GEX_pct_counts_mt', 'GEX_size_factors', 'GEX_phase', 'ADT_n_antibodies_by_counts', 'ADT_total_counts', 'ADT_iso_count', 'cell_type', 'batch', 'ADT_pseudotime_order', 'GEX_pseudotime_order', 'Samplename', 'Site', 'DonorNumber', 'Modality', 'VendorLot', 'DonorID', 'DonorAge', 'DonorBMI', 'DonorBloodType', 'DonorRace', 'Ethnicity', 'DonorGender', 'QCMeds', 'DonorSmoker', 'is_train'
#     var: 'feature_types', 'gene_id'
#     uns: 'dataset_id', 'genome', 'organism'
#     obsm: 'ADT_X_pca', 'ADT_X_umap', 'ADT_isotype_controls', 'GEX_X_pca', 'GEX_X_umap'
#     layers: 'clr', 'counts'

# %%
print(adata_adt.X)
# Out:
# <Compressed Sparse Column sparse matrix of dtype 'float32'
# 	with 2245975 stored elements and shape (20000, 134)>
#   Coords	Values
#   (0, 0)	0.6684538125991821
#   (1, 0)	0.8865846395492554
#   (2, 0)	0.8865846395492554
#   (3, 0)	0.3890708088874817
#   (4, 0)	1.750258445739746
#   (5, 0)	0.8865846395492554
#   (6, 0)	0.6684538125991821
#   (7, 0)	1.5696303844451904
#   (8, 0)	0.3890708088874817
#   (9, 0)	0.3890708088874817
#   (10, 0)	0.3890708088874817
#   (11, 0)	0.3890708088874817
#   (12, 0)	1.2172971963882446
#   (13, 0)	1.4653973579406738
#   (14, 0)	0.6684538125991821
#   (15, 0)	1.065550446510315
#   (16, 0)	0.6684538125991821
#   (18, 0)	1.065550446510315
#   (19, 0)	3.575695514678955
#   (21, 0)	1.2172971963882446
#   (22, 0)	0.3890708088874817
#   (24, 0)	0.6684538125991821
#   (25, 0)	1.5696303844451904
#   (26, 0)	3.0657799243927
#   (27, 0)	0.3890708088874817
#   :	:
#   (19971, 133)	0.19750525057315826
#   (19972, 133)	0.36236199736595154
#   (19973, 133)	1.0104641914367676
#   (19974, 133)	0.6277751326560974
#   (19975, 133)	0.1036207526922226
#   (19976, 133)	0.36236199736595154
#   (19978, 133)	0.1036207526922226
#   (19979, 133)	0.1036207526922226
#   (19980, 133)	0.5038483738899231
#   (19981, 133)	0.43560540676116943
#   (19982, 133)	0.28332701325416565
#   (19983, 133)	0.19750525057315826
#   (19986, 133)	0.19750525057315826
#   (19987, 133)	1.0104641914367676
#   (19988, 133)	0.19750525057315826
#   (19989, 133)	0.43560540676116943
#   (19990, 133)	0.7380236983299255
#   (19991, 133)	0.28332701325416565
#   (19992, 133)	0.43560540676116943
#   (19993, 133)	0.5677302479743958
#   (19994, 133)	0.7380236983299255
#   (19996, 133)	0.43560540676116943
#   (19997, 133)	0.5677302479743958
#   (19998, 133)	0.28332701325416565
#   (19999, 133)	0.36236199736595154

# %%
adata_adt.X = adata_adt.layers["counts"].copy()

# %%
import muon
muon.prot.pp.clr(adata_adt)
adata_adt.layers["clr"] = adata_adt.X.copy()

# %%
X = adata_rna.obsm["X_uce"]
# hvg_mask = adata_rna.var["hvg"].values
# X = X[:, hvg_mask]
y = adata_adt.layers["clr"]

# %%
X.shape
# Out:
# (20000, 1280)

# %%
y.shape
# Out:
# (20000, 134)

# %%
X = X.toarray() if hasattr(X, "toarray") else X
y = y.toarray() if hasattr(y, "toarray") else y

# %% [markdown]
# # Model

# %%
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np

kf = KFold(n_splits=5, shuffle=True, random_state=42)

model = LinearRegression()
mse_scores = []

for train_idx, test_idx in kf.split(X):
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

# %%
import numpy as np
from sklearn.metrics import mean_squared_error

# per-protein MSE
mse_per_protein = ((y_test - y_pred) ** 2).mean(axis=0)

# overall mean
avg_mse = mse_per_protein.mean()

print("Avg MSE:", avg_mse)
print("Per-protein MSE:", mse_per_protein)
print("Per-protein MSE shape:", mse_per_protein.shape)
# Out:
# Avg MSE: 0.22703023
# Per-protein MSE: [0.2512293  0.2099734  0.11890941 0.16133343 0.14945891 0.23733018
#  0.23262656 0.1637665  0.12076794 0.25124913 0.26946744 0.43044183
#  0.24209584 0.20939736 0.29261884 0.29253602 0.30647457 0.33236706
#  0.24711876 0.4127424  0.13144769 0.21343414 0.21509165 0.33751407
#  0.30971044 0.20339714 0.27947503 0.2010271  0.24313948 0.13523376
#  0.16818851 0.22733423 0.163378   0.3693314  0.13836586 0.21384683
#  0.302372   0.30248103 0.16537817 0.33765802 0.31906164 0.16308686
#  0.21583913 0.2508765  0.41667897 0.20745079 0.12338665 0.1444087
#  0.32040486 0.29748428 0.1804204  0.13656409 0.14365986 0.34988138
#  0.25295427 0.24050303 0.20659968 0.12279093 0.15827665 0.1678971
#  0.3065163  0.18199    0.18691903 0.16174519 0.1830151  0.29452208
#  0.11843767 0.17020263 0.24127176 0.3040158  0.15161902 0.28414187
#  0.17059134 0.27823976 0.22271957 0.17349517 0.27169454 0.2412922
#  0.14185883 0.18596615 0.18299104 0.17251395 0.1855622  0.4057797
#  0.13960758 0.1416873  0.10743985 0.13323754 0.19858417 0.31711805
#  0.23225984 0.24125722 0.1451761  0.2266982  0.3069999  0.26718536
#  0.21082217 0.1379039  0.3152124  0.19908224 0.24620144 0.22903663
#  0.30497685 0.30810043 0.14820099 0.25394842 0.15128034 0.36624235
#  0.15381102 0.27461982 0.28246602 0.19321212 0.2500905  0.2834916
#  0.26130474 0.54732966 0.2287141  0.17033547 0.14895287 0.16679595
#  0.24877131 0.15412806 0.17563099 0.1970879  0.23153806 0.27689105
#  0.18923046 0.11750879 0.3090492  0.1339419  0.27614185 0.217569
#  0.17991811 0.20022455]
# Per-protein MSE shape: (134,)

# %%
rmse_per_protein = np.sqrt(mse_per_protein)
avg_rmse = rmse_per_protein.mean()

print("Avg RMSE:", avg_rmse)
print("Per-protein RMSE:", rmse_per_protein)
print("Per-protein RMSE shape:", rmse_per_protein.shape)
# Out:
# Avg RMSE: 0.47000217
# Per-protein RMSE: [0.5012278  0.45822853 0.34483245 0.40166333 0.38659915 0.48716545
#  0.48231375 0.40468073 0.3475168  0.5012476  0.5191025  0.65608066
#  0.49203235 0.45759955 0.54094255 0.540866   0.55360144 0.5765129
#  0.4971104  0.64245033 0.36255714 0.46198934 0.46377975 0.5809596
#  0.55651635 0.4509957  0.528654   0.44836044 0.49309176 0.36774144
#  0.41010794 0.4767958  0.40420043 0.6077264  0.37197563 0.46243575
#  0.5498836  0.5499827  0.40666714 0.5810835  0.5648554  0.40384015
#  0.46458492 0.5008757  0.64550674 0.45546767 0.35126436 0.38001144
#  0.56604314 0.5454212  0.42475924 0.3695458  0.3790249  0.59150773
#  0.5029456  0.49041107 0.45453238 0.35041538 0.39783996 0.4097525
#  0.5536391  0.42660287 0.43234134 0.40217558 0.42780262 0.54269886
#  0.34414774 0.4125562  0.49119422 0.5513763  0.38938287 0.5330496
#  0.41302705 0.52748436 0.47193173 0.4165275  0.5212433  0.49121502
#  0.3766415  0.43123794 0.42777452 0.415348   0.4307693  0.63700837
#  0.37364098 0.37641373 0.3277802  0.36501718 0.44562784 0.56313235
#  0.48193344 0.4911794  0.3810198  0.47612834 0.5540757  0.51689976
#  0.45915374 0.37135413 0.5614378  0.44618633 0.4961869  0.4785777
#  0.5522471  0.55506796 0.38496882 0.50393295 0.38894773 0.6051796
#  0.39218748 0.52404183 0.5314753  0.439559   0.5000905  0.5324393
#  0.51117975 0.7398173  0.4782406  0.4127172  0.38594413 0.40840662
#  0.4987698  0.39259148 0.4190835  0.44394583 0.481184   0.5262044
#  0.43500626 0.34279555 0.5559219  0.36598074 0.525492   0.4664429
#  0.42416754 0.4474646 ]
# Per-protein RMSE shape: (134,)

# %%
from scipy.stats import pearsonr

pearson_per_protein = []

for i in range(y_test.shape[1]):
    if np.std(y_test[:, i]) > 0 and np.std(y_pred[:, i]) > 0:
        corr, _ = pearsonr(y_test[:, i], y_pred[:, i])
    else:
        corr = np.nan
    pearson_per_protein.append(corr)

pearson_per_protein = np.array(pearson_per_protein)
mean_pearson = np.nanmean(pearson_per_protein)

print("Avg Pearson correlation:", mean_pearson)
print("Per-protein Pearson correlation:", pearson_per_protein)
print("Per-protein Pearson shape:", pearson_per_protein.shape)
# Out:
# Avg Pearson correlation: 0.69051063
# Per-protein Pearson correlation: [0.71358716 0.5584409  0.6525026  0.56985146 0.5936558  0.7585385
#  0.7987993  0.73200333 0.59957397 0.80472744 0.88310045 0.8325309
#  0.6874727  0.88547146 0.8130901  0.8502908  0.7604575  0.8379469
#  0.73446923 0.8685994  0.5828078  0.6873357  0.6301564  0.81158596
#  0.7487917  0.73676145 0.8176694  0.49120376 0.7351994  0.60515195
#  0.609284   0.7805062  0.60943294 0.771292   0.560372   0.40560374
#  0.73431873 0.890988   0.62305963 0.8270432  0.64551294 0.65629756
#  0.4950385  0.54335356 0.63944036 0.647715   0.59847105 0.5325973
#  0.78251696 0.836704   0.59805983 0.72161543 0.528709   0.7609426
#  0.68966657 0.78642887 0.71567434 0.60326207 0.6238212  0.7478847
#  0.8518748  0.6478489  0.70139384 0.7498612  0.7045531  0.7300425
#  0.64735603 0.7673824  0.80214787 0.7995803  0.6507703  0.8019663
#  0.43881428 0.66098    0.76812184 0.4093508  0.7055366  0.73576784
#  0.59603125 0.77601594 0.6187411  0.69830143 0.62653625 0.84466887
#  0.56539434 0.5435662  0.6208097  0.6078108  0.6695321  0.881555
#  0.7308525  0.7059982  0.5482193  0.66532224 0.8045294  0.8302768
#  0.7649383  0.7625509  0.7743285  0.7873688  0.8386239  0.85497445
#  0.91946316 0.7758522  0.6530853  0.7395542  0.56816524 0.8491663
#  0.85270745 0.8890264  0.47497538 0.67105585 0.42385542 0.7249949
#  0.7152208  0.754906   0.51259536 0.26017374 0.5114888  0.486526
#  0.35263887 0.5158803  0.6056185  0.85795426 0.6982715  0.7677419
#  0.5978277  0.606661   0.8122952  0.66992366 0.7383189  0.71731293
#  0.735645   0.63184977]
# Per-protein Pearson shape: (134,)

# %%
import numpy as np

corrs = []
for i in range(y.shape[1]):
    corr = np.corrcoef(y_test[:, i], y_pred[:, i])[0,1]
    corrs.append(corr)

print("Avg correlation:", np.mean(corrs))
# Out:
# Avg correlation: 0.6905106873358461

# %%
from scipy.stats import spearmanr

spearman_per_protein = []

for i in range(y_test.shape[1]):
    if np.std(y_test[:, i]) > 0 and np.std(y_pred[:, i]) > 0:
        corr, _ = spearmanr(y_test[:, i], y_pred[:, i])
    else:
        corr = np.nan
    spearman_per_protein.append(corr)

spearman_per_protein = np.array(spearman_per_protein)
mean_spearman = np.nanmean(spearman_per_protein)

print("Mean Spearman correlation:", mean_spearman)
print("Per-protein Spearman correlation:", spearman_per_protein)
print("Per-protein Spearman shape:", spearman_per_protein.shape)
# Out:
# Mean Spearman correlation: 0.6003260926357695
# Per-protein Spearman correlation: [0.57706085 0.51683495 0.64806505 0.49425554 0.54208862 0.71481105
#  0.79073264 0.53950735 0.60897606 0.73923358 0.73512423 0.56765018
#  0.53690332 0.60130796 0.67182453 0.73179163 0.73712109 0.79059195
#  0.52221633 0.7811937  0.57610866 0.64576446 0.31104431 0.62774134
#  0.71892182 0.60195343 0.51321137 0.37438181 0.61852252 0.60639198
#  0.5916697  0.59915341 0.53007202 0.77099318 0.57051578 0.39733235
#  0.66918926 0.79558073 0.51934257 0.75672115 0.55111662 0.56844346
#  0.42675155 0.39548014 0.59812171 0.54802994 0.60207658 0.52626694
#  0.54254719 0.64423847 0.59202599 0.67772826 0.52892295 0.67833183
#  0.41261603 0.67606122 0.56220432 0.60480237 0.59089077 0.63036032
#  0.77878716 0.49438379 0.5859785  0.66848708 0.66867257 0.64599574
#  0.61375898 0.64141023 0.49190078 0.77805508 0.5279837  0.68195578
#  0.43843427 0.58673527 0.45998516 0.38331916 0.66682235 0.52798217
#  0.57981033 0.66457837 0.55037204 0.57359613 0.57030375 0.62012441
#  0.56856255 0.53570579 0.62756888 0.60395509 0.57178032 0.77587283
#  0.5868787  0.67783116 0.52951332 0.57500591 0.72751246 0.42463436
#  0.75855386 0.68339422 0.66987869 0.65121348 0.79866026 0.50395044
#  0.73658923 0.62230808 0.6152065  0.72799303 0.53845839 0.80421493
#  0.70484861 0.57028566 0.4582918  0.51868929 0.33607484 0.69646799
#  0.61598397 0.69118076 0.35145744 0.23295729 0.51039887 0.49188919
#  0.35573553 0.51129955 0.60111521 0.77261189 0.55381477 0.75450948
#  0.55656029 0.60885513 0.72620068 0.64912476 0.67711921 0.70870499
#  0.65481378 0.62111101]
# Per-protein Spearman shape: (134,)

# %%
valid_idx = np.where(~np.isnan(pearson_per_protein))[0]
valid_scores = pearson_per_protein[valid_idx]

sorted_idx = valid_idx[np.argsort(valid_scores)]

worst_idx = sorted_idx[0]
median_idx = sorted_idx[len(sorted_idx)//2]
best_idx = sorted_idx[-1]

selected_idx = [worst_idx, median_idx, best_idx]
labels = ["Worst", "Median", "Best"]

protein_names = np.array(adata_adt.var_names)

print("\nSelected proteins:")
for label, idx in zip(labels, selected_idx):
    print(
        f"{label}: {protein_names[idx]} "
        f"(Pearson = {pearson_per_protein[idx]:.4f})"
    )
# Out:
# Selected proteins:
# Worst: TCRVd2 (Pearson = 0.2736)
# Median: IgM (Pearson = 0.7271)
# Best: CD71 (Pearson = 0.9262)

# %%
import matplotlib.pyplot as plt

for label, idx in zip(labels, selected_idx):

    x = y_test[:, idx]
    yhat = y_pred[:, idx]

    plt.figure(figsize=(6,6))

    plt.scatter(
        x,
        yhat,
        s=10,
        alpha=0.25
    )

    mn = min(x.min(), yhat.min())
    mx = max(x.max(), yhat.max())

    plt.plot([mn, mx], [mn, mx], "--", linewidth=2)

    plt.xlabel("Measured Expression")
    plt.ylabel("Predicted Expression")

    plt.title(
        f"{label} Protein: {protein_names[idx]}\n"
        f"Pearson = {pearson_per_protein[idx]:.4f}"
    )

    plt.tight_layout()
    plt.show()

# %%
from pathlib import Path
import numpy as np

save_path = Path("/content/drive/MyDrive/GP_datasets/results")
save_path.mkdir(parents=True, exist_ok=True)

model_name = "UCE"  # change per notebook

np.savez(
    save_path / f"{model_name}_bone_marrow_protein_results.npz",

    # raw outputs
    y_test=y_test,
    y_pred=y_pred,

    # metadata
    protein_names=protein_names,

    # metrics
    pearson_per_protein=pearson_per_protein,

    # selected indices (diagnostic)
    worst_idx=worst_idx,
    median_idx=median_idx,
    best_idx=best_idx,

    selected_idx=np.array(selected_idx),

    mean_pearson=np.nanmean(pearson_per_protein),
)

print(f"Saved results for {model_name} at:", save_path)
# Out:
# Saved results for UCE at: /content/drive/MyDrive/GP_datasets/results
