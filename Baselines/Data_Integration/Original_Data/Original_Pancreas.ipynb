# %%
# !pip install scanpy==1.9.3 anndata==0.8.0
# !pip install scikit-learn
# !pip install matplotlib
# !pip install pandas
# !pip install numpy
# !pip install harmonypy
# !pip install scvi-tools
# Out:
# Collecting scanpy==1.9.3
#   Downloading scanpy-1.9.3-py3-none-any.whl.metadata (6.1 kB)
# Collecting anndata==0.8.0
#   Downloading anndata-0.8.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from scanpy==1.9.3) (2.0.2)
# Requirement already satisfied: matplotlib>=3.4 in /usr/local/lib/python3.12/dist-packages (from scanpy==1.9.3) (3.10.0)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.12/dist-packages (from scanpy==1.9.3) (2.2.2)
# Requirement already satisfied: scipy>=1.4 in /usr/local/lib/python3.12/dist-packages (from scanpy==1.9.3) (1.16.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from scanpy==1.9.3) (0.13.2)
# Requirement already satisfied: h5py>=3 in /usr/local/lib/python3.12/dist-packages (from scanpy==1.9.3) (3.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from scanpy==1.9.3) (4.67.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.12/dist-packages (from scanpy==1.9.3) (1.6.1)
# Requirement already satisfied: statsmodels>=0.10.0rc2 in /usr/local/lib/python3.12/dist-packages (from scanpy==1.9.3) (0.14.6)
# Requirement already satisfied: patsy in /usr/local/lib/python3.12/dist-packages (from scanpy==1.9.3) (1.0.2)
# Requirement already satisfied: networkx>=2.3 in /usr/local/lib/python3.12/dist-packages (from scanpy==1.9.3) (3.6.1)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from scanpy==1.9.3) (8.4.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from scanpy==1.9.3) (1.5.3)
# Requirement already satisfied: numba>=0.41.0 in /usr/local/lib/python3.12/dist-packages (from scanpy==1.9.3) (0.60.0)
# Requirement already satisfied: umap-learn>=0.3.10 in /usr/local/lib/python3.12/dist-packages (from scanpy==1.9.3) (0.5.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from scanpy==1.9.3) (26.1)
# Collecting session-info (from scanpy==1.9.3)
#   Downloading session_info-1.0.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4->scanpy==1.9.3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4->scanpy==1.9.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4->scanpy==1.9.3) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4->scanpy==1.9.3) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4->scanpy==1.9.3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4->scanpy==1.9.3) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4->scanpy==1.9.3) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.41.0->scanpy==1.9.3) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0->scanpy==1.9.3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0->scanpy==1.9.3) (2026.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22->scanpy==1.9.3) (3.6.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.12/dist-packages (from umap-learn>=0.3.10->scanpy==1.9.3) (0.6.0)
# Collecting stdlib_list (from session-info->scanpy==1.9.3)
#   Downloading stdlib_list-0.12.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.4->scanpy==1.9.3) (1.17.0)
# Downloading scanpy-1.9.3-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 35.6 MB/s eta 0:00:00
# Downloading anndata-0.8.0-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.1/96.1 kB 5.1 MB/s eta 0:00:00
# Downloading session_info-1.0.1-py3-none-any.whl (9.1 kB)
# Downloading stdlib_list-0.12.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 4.5 MB/s eta 0:00:00
# Installing collected packages: stdlib_list, session-info, anndata, scanpy
# Successfully installed anndata-0.8.0 scanpy-1.9.3 session-info-1.0.1 stdlib_list-0.12.0
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Collecting harmonypy
#   Downloading harmonypy-2.0.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from harmonypy) (2.0.2)
# Downloading harmonypy-2.0.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 82.1 MB/s eta 0:00:00
# Installing collected packages: harmonypy
# Successfully installed harmonypy-2.0.0
# Collecting scvi-tools
#   Downloading scvi_tools-1.4.2-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: anndata in /usr/local/lib/python3.12/dist-packages (from scvi-tools) (0.8.0)
# Collecting docrep>=0.3.2 (from scvi-tools)
#   Downloading docrep-0.3.2.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Collecting lightning>=2.0 (from scvi-tools)
#   Downloading lightning-2.6.1-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.9 MB/s eta 0:00:00
# Collecting ml-collections (from scvi-tools)
#   Downloading ml_collections-1.1.0-py3-none-any.whl.metadata (22 kB)
# Collecting mudata (from scvi-tools)
#   Downloading mudata-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numba>=0.60.0 in /usr/local/lib/python3.12/dist-packages (from scvi-tools) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from scvi-tools) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from scvi-tools) (2.2.2)
# Collecting pyro-ppl (from scvi-tools)
#   Downloading pyro_ppl-1.9.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from scvi-tools) (13.9.4)
# Collecting scanpy>=1.10 (from scanpy[skmisc]>=1.10->scvi-tools)
#   Downloading scanpy-1.12.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from scvi-tools) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from scvi-tools) (1.16.3)
# Collecting sparse>=0.14.0 (from scvi-tools)
#   Downloading sparse-0.18.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from scvi-tools) (2.20.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from scvi-tools) (2.10.0+cpu)
# Collecting torchmetrics (from scvi-tools)
#   Downloading torchmetrics-1.9.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from scvi-tools) (4.67.3)
# Requirement already satisfied: xarray in /usr/local/lib/python3.12/dist-packages (from scvi-tools) (2025.12.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from docrep>=0.3.2->scvi-tools) (1.17.0)
# Requirement already satisfied: PyYAML<8.0,>5.4 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0->scvi-tools) (6.0.3)
# Requirement already satisfied: fsspec<2028.0,>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools) (2025.3.0)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning>=2.0->scvi-tools)
#   Downloading lightning_utilities-0.15.3-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: packaging<27.0,>=23.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0->scvi-tools) (26.1)
# Requirement already satisfied: typing-extensions<6.0,>4.5.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0->scvi-tools) (4.15.0)
# Collecting pytorch-lightning (from lightning>=2.0->scvi-tools)
#   Downloading pytorch_lightning-2.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.60.0->scvi-tools) (0.43.0)
# Collecting anndata (from scvi-tools)
#   Downloading anndata-0.12.13-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (2026.4.22)
# Collecting fast-array-utils>=1.4 (from fast-array-utils[accel,sparse]>=1.4->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools)
#   Downloading fast_array_utils-1.4.1-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: h5py>=3.11 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (3.16.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (1.5.3)
# Collecting legacy-api-wrap>=1.5 (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools)
#   Downloading legacy_api_wrap-1.5-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: matplotlib>=3.9 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (3.10.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (8.4.0)
# Requirement already satisfied: networkx>=2.8.8 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (3.6.1)
# Collecting pandas (from scvi-tools)
#   Downloading pandas-3.0.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: patsy in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5.13 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (0.6.0)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (0.13.2)
# Collecting session-info2 (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools)
#   Downloading session_info2-0.4.1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (0.14.6)
# Requirement already satisfied: umap-learn>=0.5.12 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (0.5.12)
# Collecting array-api-compat>=1.7.1 (from anndata->scvi-tools)
#   Downloading array_api_compat-1.14.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pandas (from scvi-tools)
#   Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 2.8 MB/s eta 0:00:00
# Collecting scverse-misc>=0.0.3 (from anndata->scvi-tools)
#   Downloading scverse_misc-0.0.6-py3-none-any.whl.metadata (4.5 kB)
# Collecting zarr!=3.0.*,>=2.18.7 (from anndata->scvi-tools)
#   Downloading zarr-3.2.1-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->scvi-tools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->scvi-tools) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->scvi-tools) (2026.1)
# Collecting scikit-misc>=0.5.1 (from scanpy[skmisc]>=1.10->scvi-tools)
#   Downloading scikit_misc-0.5.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->scvi-tools) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (3.29.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools) (3.1.6)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from ml-collections->scvi-tools) (1.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from pyro-ppl->scvi-tools) (3.4.0)
# Collecting pyro-api>=0.1.1 (from pyro-ppl->scvi-tools)
#   Downloading pyro_api-0.1.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->scvi-tools) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->scvi-tools) (2.20.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->scvi-tools) (1.80.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->scvi-tools) (3.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard->scvi-tools) (11.3.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard->scvi-tools) (5.29.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->scvi-tools) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->scvi-tools) (3.1.8)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools) (3.13.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->scvi-tools) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (3.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->scvi-tools) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard->scvi-tools) (3.0.3)
# Collecting donfig>=0.8 (from zarr!=3.0.*,>=2.18.7->anndata->scvi-tools)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata->scvi-tools) (1.8.0)
# Collecting numcodecs>=0.14 (from zarr!=3.0.*,>=2.18.7->anndata->scvi-tools)
#   Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools) (1.23.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools) (3.13)
# Downloading scvi_tools-1.4.2-py3-none-any.whl (662 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 662.1/662.1 kB 10.5 MB/s eta 0:00:00
# Downloading lightning-2.6.1-py3-none-any.whl (853 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 853.6/853.6 kB 19.1 MB/s eta 0:00:00
# Downloading scanpy-1.12.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 30.7 MB/s eta 0:00:00
# Downloading anndata-0.12.13-py3-none-any.whl (174 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.4/174.4 kB 10.9 MB/s eta 0:00:00
# Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 52.1 MB/s eta 0:00:00
# Downloading sparse-0.18.0-py2.py3-none-any.whl (151 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.9/151.9 kB 6.5 MB/s eta 0:00:00
# Downloading torchmetrics-1.9.0-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 24.4 MB/s eta 0:00:00
# Downloading ml_collections-1.1.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 4.2 MB/s eta 0:00:00
# Downloading mudata-0.3.8-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 1.8 MB/s eta 0:00:00
# Downloading pyro_ppl-1.9.1-py3-none-any.whl (755 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 20.6 MB/s eta 0:00:00
# Downloading array_api_compat-1.14.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 4.6 MB/s eta 0:00:00
# Downloading fast_array_utils-1.4.1-py3-none-any.whl (39 kB)
# Downloading legacy_api_wrap-1.5-py3-none-any.whl (10 kB)
# Downloading lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Downloading pyro_api-0.1.2-py3-none-any.whl (11 kB)
# Downloading scikit_misc-0.5.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.0/183.0 kB 12.4 MB/s eta 0:00:00
# Downloading scverse_misc-0.0.6-py3-none-any.whl (13 kB)
# Downloading zarr-3.2.1-py3-none-any.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.6/319.6 kB 18.2 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.6.1-py3-none-any.whl (857 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.3/857.3 kB 26.6 MB/s eta 0:00:00
# Downloading session_info2-0.4.1-py3-none-any.whl (17 kB)
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 68.9 MB/s eta 0:00:00
# Building wheels for collected packages: docrep
#   Building wheel for docrep (setup.py) ... done
#   Created wheel for docrep: filename=docrep-0.3.2-py3-none-any.whl size=19876 sha256=a039d18c65b56c9f5af80e914ad62b60982aa1b5b53dfe3a8cc155df022fa0b4
#   Stored in directory: /root/.cache/pip/wheels/d6/19/ee/0a6a1793d91c449563b49ccab57ce52da3e6fab7614836bd8c
# Successfully built docrep
# Installing collected packages: pyro-api, session-info2, scikit-misc, numcodecs, ml-collections, lightning-utilities, legacy-api-wrap, fast-array-utils, donfig, docrep, array-api-compat, zarr, sparse, scverse-misc, pandas, torchmetrics, pyro-ppl, anndata, pytorch-lightning, mudata, scanpy, lightning, scvi-tools
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: anndata
#     Found existing installation: anndata 0.8.0
#     Uninstalling anndata-0.8.0:
#       Successfully uninstalled anndata-0.8.0
#   Attempting uninstall: scanpy
#     Found existing installation: scanpy 1.9.3
#     Uninstalling scanpy-1.9.3:
#       Successfully uninstalled scanpy-1.9.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# Successfully installed anndata-0.12.13 array-api-compat-1.14.0 docrep-0.3.2 donfig-0.8.1.post1 fast-array-utils-1.4.1 legacy-api-wrap-1.5 lightning-2.6.1 lightning-utilities-0.15.3 ml-collections-1.1.0 mudata-0.3.8 numcodecs-0.16.5 pandas-2.3.3 pyro-api-0.1.2 pyro-ppl-1.9.1 pytorch-lightning-2.6.1 scanpy-1.12.1 scikit-misc-0.5.2 scverse-misc-0.0.6 scvi-tools-1.4.2 session-info2-0.4.1 sparse-0.18.0 torchmetrics-1.9.0 zarr-3.2.1

# %%
import scanpy as sc
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Dataset

# %%
# import anndata as ad

data_path = "/content/drive/MyDrive/GP_datasets/Pancreas/Baron_Pancreas_Human_mix.h5ad"

# %%
# read adata
adata = sc.read_h5ad(data_path)

# %%
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 8569 × 16381
#     obs: 'donor_id', 'cell_type', 'barcode', 'donor_batch'

# %%
adata.var.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [A1BG, A1CF, A2M, A2ML1, A4GALT]

# %%
adata.obs.head()
# Out:
#                             donor_id cell_type              barcode  \
# Cell_id
# human1_lib1.final_cell_0001   human1    acinar  GATGACGGAC-GGTGGGAT
# human1_lib1.final_cell_0002   human1    acinar  GAGCGTTGCT-ACCTTCTT
# human1_lib1.final_cell_0003   human1    acinar    CTTACGGG-CCATTACT
# human1_lib1.final_cell_0004   human1    acinar  GATGTACACG-TTAAACTG
# human1_lib1.final_cell_0005   human1    acinar  GAGATTGCGA-GTCGTCGT
#
#                             donor_batch
# Cell_id
# human1_lib1.final_cell_0001    subject1
# human1_lib1.final_cell_0002    subject1
# human1_lib1.final_cell_0003    subject1
# human1_lib1.final_cell_0004    subject1
# human1_lib1.final_cell_0005    subject1

# %%
# add disease column, healthy for subjects 1 to 3 and diabetes tpe 2 for subject 4
adata.obs['disease'] = adata.obs['donor_id'].apply(lambda x: 'healthy' if x in ['human1', 'human2', 'human3'] else 'diabetes_type_2')

# %%
# check cell_types
adata.obs['cell_type'].value_counts()
print(adata.obs)
# Out:
#                             donor_id           cell_type  \
# Cell_id
# human1_lib1.final_cell_0001   human1              acinar
# human1_lib1.final_cell_0002   human1              acinar
# human1_lib1.final_cell_0003   human1              acinar
# human1_lib1.final_cell_0004   human1              acinar
# human1_lib1.final_cell_0005   human1              acinar
# ...                              ...                 ...
# human4_lib3.final_cell_0697   human4  activated_stellate
# human4_lib3.final_cell_0698   human4               alpha
# human4_lib3.final_cell_0699   human4                beta
# human4_lib3.final_cell_0700   human4                beta
# human4_lib3.final_cell_0701   human4              ductal
#
#                                           barcode donor_batch          disease
# Cell_id
# human1_lib1.final_cell_0001   GATGACGGAC-GGTGGGAT    subject1          healthy
# human1_lib1.final_cell_0002   GAGCGTTGCT-ACCTTCTT    subject1          healthy
# human1_lib1.final_cell_0003     CTTACGGG-CCATTACT    subject1          healthy
# human1_lib1.final_cell_0004   GATGTACACG-TTAAACTG    subject1          healthy
# human1_lib1.final_cell_0005   GAGATTGCGA-GTCGTCGT    subject1          healthy
# ...                                           ...         ...              ...
# human4_lib3.final_cell_0697   GAGATCTCGG-GTCTCTCT    subject4  diabetes_type_2
# human4_lib3.final_cell_0698     GCTTACCT-ATGTTGGC    subject4  diabetes_type_2
# human4_lib3.final_cell_0699  TGACACAGTTT-TTGTCGCC    subject4  diabetes_type_2
# human4_lib3.final_cell_0700   GACGACTCCT-CGCTAATA    subject4  diabetes_type_2
# human4_lib3.final_cell_0701     TGATGCCC-TTGCACGC    subject4  diabetes_type_2
#
# [8569 rows x 5 columns]

# %% [markdown]
# ## Normalization

# %%
# make sure there is a counts layer for scvi
adata.layers["counts"] = adata.X

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
adata.raw = adata  # keep full dimension safe
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=4000,
    flavor="seurat_v3",
    layer="counts",
    subset=True,
    batch_key="donor_id",  # Change depending on the batch key for your dataset
)
# Out:
# /tmp/ipykernel_9446/1768548355.py:4: UserWarning: `flavor='seurat_v3'` expects raw count data, but non-integers were found.
#   sc.pp.highly_variable_genes(

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import silhouette_score
from harmonypy import compute_lisi

def compute_silhouette_and_lisi(adata, label_keys, embed_key,k_lisi=30):

    X = adata.obsm[embed_key]
    metadata = adata.obs[label_keys]


    # Silhouette scores
    sil_scores = {}
    for key in label_keys:
        sil_scores[key] = silhouette_score(X, adata.obs[key].values)


    # Call compute_lisi
    lisi_scores = compute_lisi(X, metadata, label_colnames=label_keys)

    # Convert to DataFrame for easier handling
    lisi_df = pd.DataFrame(lisi_scores, columns=label_keys, index=adata.obs_names)

    # Combine results
    scores = {
        "silhouette": sil_scores,
        "lisi": lisi_df.median().to_dict()
    }

    return scores

# %%
## Visualization
## pca
sc.pp.pca(adata, n_comps=50)
sc.pp.neighbors(adata, use_rep="X_pca")
sc.tl.umap(adata)

ax = sc.pl.umap(
    adata,
    color='cell_type',
    size=20,
    alpha=0.8,
    frameon=True,
    show=False,
    title="Original Data - Pancreas: Cell Type"
)

ax.set_facecolor("white")
ax.set_xlabel("UMAP1", fontsize=11)
ax.set_ylabel("UMAP2", fontsize=11)

# Make axis lines visible
ax.spines[['left', 'bottom']].set_visible(True)

# Remove top/right box lines (clean style)
ax.spines[['top', 'right']].set_visible(False)

# Make axes black
ax.spines[['left', 'bottom']].set_color("black")

plt.show()

ax = sc.pl.umap(
    adata,
    color='donor_id',
    size=20,
    alpha=0.8,
    frameon=True,
    show=False,
    title="Original Data - Pancreas: Batch Label"
)

ax.set_facecolor("white")
ax.set_xlabel("UMAP1", fontsize=11)
ax.set_ylabel("UMAP2", fontsize=11)

# Make axis lines visible
ax.spines[['left', 'bottom']].set_visible(True)

# Remove top/right box lines (clean style)
ax.spines[['top', 'right']].set_visible(False)

# Make axes black
ax.spines[['left', 'bottom']].set_color("black")

plt.show()

ax = sc.pl.umap(
    adata,
    color='disease',
    size=20,
    alpha=0.8,
    frameon=True,
    show=False,
    title="Original Data - Pancreas: Dataset"
)

ax.set_facecolor("white")
ax.set_xlabel("UMAP1", fontsize=11)
ax.set_ylabel("UMAP2", fontsize=11)

# Make axis lines visible
ax.spines[['left', 'bottom']].set_visible(True)

# Remove top/right box lines (clean style)
ax.spines[['top', 'right']].set_visible(False)

# Make axes black
ax.spines[['left', 'bottom']].set_color("black")

plt.show()

## Build a cell-type classifier using Geneformer embeddings  3 batches for train and 1 for test

train_data = adata[adata.obs["disease"] == "healthy"].copy()
test_data = adata[adata.obs["disease"] == "diabetes_type_2"].copy()

X_train = train_data.X
X_test  = test_data.X

y_train = train_data.obs["cell_type"]
y_test  = test_data.obs["cell_type"]


# logistic regression
clf = LogisticRegression(max_iter=300, multi_class='multinomial', solver='lbfgs')

clf.fit(X_train, y_train)
y_pred_lr = clf.predict(X_test)

# KNN
knn = KNeighborsClassifier(
    n_neighbors=15,
    weights="distance",
    metric="cosine"
)

knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)

def plot_cm(y_true, y_pred, title):
    labels = np.unique(y_true)
    cm = confusion_matrix(y_true, y_pred, labels=labels, normalize="true")

    fig, ax = plt.subplots(figsize=(10, 8), dpi=100)

    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=labels)

    disp.plot(
        ax=ax,
        cmap="Blues",
        xticks_rotation=90,
        values_format=".2f",
        colorbar=True
    )

    # Make text smaller
    for text in ax.texts:
        text.set_fontsize(7)

    plt.title(title, fontsize=16)
    plt.xlabel("Predicted label", fontsize=12)
    plt.ylabel("True label", fontsize=12)

    plt.tight_layout()
    plt.show()

print("=== Logistic Regression ===")
print("Accuracy:", accuracy_score(y_test, y_pred_lr))
print(classification_report(y_test, y_pred_lr))
plot_cm(y_test, y_pred_lr, "Logistic Regression Confusion Matrix")


print("\n=== k-NN ===")
print("Accuracy:", accuracy_score(y_test, y_pred_knn))
print(classification_report(y_test, y_pred_knn))
plot_cm(y_test, y_pred_knn, "k-NN Confusion Matrix")

# Attach predictions to test dataset
test_data.obs["y_pred_lr"] = y_pred_lr
test_data.obs["y_pred_knn"] = y_pred_knn

# Fill missing values
test_data.obs["y_pred_lr"] = test_data.obs["y_pred_lr"].astype(str).fillna("Unassigned")
test_data.obs["y_pred_knn"] = test_data.obs["y_pred_knn"].astype(str).fillna("Unassigned")

# Convert to categorical
test_data.obs["cell_type"] = test_data.obs["cell_type"].astype("category") # Changed from celltype to cell_type
test_data.obs["y_pred_lr"] = test_data.obs["y_pred_lr"].astype("category")
test_data.obs["y_pred_knn"] = test_data.obs["y_pred_knn"].astype("category")

# Unified label set
all_labels = sorted(
    set(test_data.obs["cell_type"].cat.categories)
    | set(test_data.obs["y_pred_lr"].cat.categories)
    | set(test_data.obs["y_pred_knn"].cat.categories)
)

# Force same category order
test_data.obs["cell_type"] = test_data.obs["cell_type"].cat.set_categories(all_labels)
test_data.obs["y_pred_lr"] = test_data.obs["y_pred_lr"].cat.set_categories(all_labels)
test_data.obs["y_pred_knn"] = test_data.obs["y_pred_knn"].cat.set_categories(all_labels)

# Color map
palette = sc.pl.palettes.vega_20
color_map = {label: palette[i % len(palette)] for i, label in enumerate(all_labels)}
color_map["Unassigned"] = "lightgray"

# Plot
fig, axes = plt.subplots(1, 3, figsize=(20, 5), dpi=150)

common_kwargs = dict(
    show=False,
    size=18,
    frameon=True,
    palette=color_map
)

# True labels
sc.pl.umap(test_data, color="cell_type", ax=axes[0], **common_kwargs)
axes[0].set_title("True Cell Types (Test Set)", fontsize=13)

# Logistic Regression predictions
sc.pl.umap(test_data, color="y_pred_lr", ax=axes[1], alpha=0.9, **common_kwargs)
axes[1].set_title("Predicted (Logistic Regression)", fontsize=13)

# KNN predictions
sc.pl.umap(test_data, color="y_pred_knn", ax=axes[2], alpha=0.9, **common_kwargs)
axes[2].set_title("Predicted (k-NN)", fontsize=13)

# Remove auto legends
for ax in axes:
    # Remove auto legend
    if ax.legend_:
        ax.legend_.remove()

    # Force white background
    ax.set_facecolor("white")

    # Axis labels
    ax.set_xlabel("UMAP1", fontsize=11)
    ax.set_ylabel("UMAP2", fontsize=11)

    # Make axis lines visible
    ax.spines[['left', 'bottom']].set_visible(True)

    # Remove top/right box lines (clean style)
    ax.spines[['top', 'right']].set_visible(False)

    # Make axes black
    ax.spines[['left', 'bottom']].set_color("black")

    # Ticks
    ax.tick_params(
        axis='both',
        which='major',
        labelsize=9,
        colors='black'
    )
# Single clean legend
from matplotlib.patches import Patch
handles = [Patch(color=color_map[label], label=label) for label in all_labels]
fig.legend(
    handles=handles,
    title="Pancreas Cell Types",
    loc="center right",
    frameon=False,
    fontsize=9,
    title_fontsize=11,
    ncol=1
)
plt.subplots_adjust(right=0.75, wspace=0.25)
# plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# === Logistic Regression ===
# Accuracy: 0.9562547966231773
#                     precision    recall  f1-score   support
#
#             acinar       0.05      1.00      0.09         2
# activated_stellate       0.98      0.98      0.98        52
#              alpha       0.99      1.00      0.99       284
#               beta       1.00      0.97      0.99       495
#              delta       0.93      1.00      0.96       101
#             ductal       1.00      0.85      0.92       280
#        endothelial       1.00      1.00      1.00         7
#            epsilon       1.00      1.00      1.00         1
#              gamma       0.94      1.00      0.97        63
#         macrophage       1.00      1.00      1.00        10
#               mast       1.00      1.00      1.00         1
# quiescent_stellate       0.83      1.00      0.91         5
#            schwann       0.00      0.00      0.00         1
#             t_cell       1.00      1.00      1.00         1
#
#           accuracy                           0.96      1303
#          macro avg       0.84      0.91      0.84      1303
#       weighted avg       0.98      0.96      0.97      1303
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# === k-NN ===
# Accuracy: 0.9539524174980814
#                     precision    recall  f1-score   support
#
#             acinar       0.05      1.00      0.09         2
# activated_stellate       0.96      1.00      0.98        52
#              alpha       0.97      1.00      0.99       284
#               beta       1.00      0.99      0.99       495
#              delta       0.98      0.99      0.99       101
#             ductal       0.99      0.84      0.91       280
#        endothelial       1.00      1.00      1.00         7
#            epsilon       1.00      1.00      1.00         1
#              gamma       0.98      0.92      0.95        63
#         macrophage       1.00      1.00      1.00        10
#               mast       1.00      1.00      1.00         1
# quiescent_stellate       1.00      0.60      0.75         5
#            schwann       0.00      0.00      0.00         1
#             t_cell       0.00      0.00      0.00         1
#
#           accuracy                           0.95      1303
#          macro avg       0.78      0.81      0.76      1303
#       weighted avg       0.98      0.95      0.97      1303
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
label_keys = ["cell_type", "donor_id", "disease"]
# Compute scores
scores = compute_silhouette_and_lisi(adata, label_keys, embed_key="X_pca", k_lisi=30)
print("Silhouette Scores:", scores["silhouette"])
print("LISI Scores:", scores["lisi"])
# Out:
# Silhouette Scores: {'cell_type': np.float32(0.22400242), 'donor_id': np.float32(0.026016047), 'disease': np.float32(0.018741373)}
# LISI Scores: {'cell_type': 1.0, 'donor_id': 1.0345481642019765, 'disease': 1.0018676979021157}
